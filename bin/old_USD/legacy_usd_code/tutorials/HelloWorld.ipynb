# %% [markdown]
# Create basic Usd stage

# %% [markdown]
# This block creates a stage and defines a standard sphere with Usd existing scheme (class)

# %%
from pxr import Usd,UsdGeom
stage = Usd.Stage.CreateNew('HelloWorld.usda')
xformPrim = UsdGeom.Xform.Define(stage, '/hello')
spherePrim = UsdGeom.Sphere.Define(stage, '/hello/world')
stage.GetRootLayer().Save()
# Out:
# True

# %% [markdown]
# Set radius of a Usd scheme 'Sphere'

# %%
# spherePrim.GetRadiusAttr().Set(2.5)
# stage.GetRootLayer().Save()

# %% [markdown]
# Translate the Shpere

# %%
# xformPrim.AddTranslateOp().Set((1, 2, 3))
# stage.GetRootLayer().Save()

# %% [markdown]
# Create Generic Prim

# %%
from pxr import Usd
stage2 = Usd.Stage.CreateNew('HelloWorldRedux.usda')
xform = stage.DefinePrim('/hello', 'Xform')
sphere = stage.DefinePrim('/hello/world', 'Sphere')
stage2.GetRootLayer().Save()
# Out:
# True

# %% [markdown]
# Retrieve basic functions from Usd standard schemes

# %%
# print(type(sphere))
# sphere = UsdGeom.Sphere(sphere)
# print(type(sphere))
# sphere.GetRadiusAttr().Set(2.5)
# stage2.GetRootLayer().Save()

# %%
# from pxr import Usd, UsdGeom, Sdf
# from usdImaging import StepImporter
# import subprocess

# def convert_step_to_usda(step_file_path, usda_file_path):
#     # Create a new USD stage in memory
#     stage = Usd.Stage.CreateInMemory()

#     # Import the STEP file into the stage
#     importer = StepImporter.Import(step_file_path, stage)

#     # Export the stage to a .usda file
#     stage.GetRootLayer().Export(usda_file_path)

# import subprocess

# def convert_step_to_usda(step_file_path, usda_file_path):
#     # Convert the STEP file to a USD file
#     subprocess.run(['usd-convert', step_file_path, usda_file_path])


# # Example usage
# step_file_path = 'input.step'
# usda_file_path = 'output.usda'
# # Example usage
# step_file_path = 'input.step'
# usda_file_path = 'output.usda'
# convert_step_to_usda('TALOS.STEP','talos.usda')

# View the .usda file in usdview
# subprocess.run(['usdview', usda_file_path])
