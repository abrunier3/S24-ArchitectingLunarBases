# %% [markdown]
# ## Habitation Module Omniverse example

# %% [markdown]
# ## Step 7 — Load Assembly into Omniverse Runtime
#
# We load the generated USD assembly into a live Omniverse
# execution context for visualization and simulation coupling.

# %%
from S24.omniverse.runtime import start_omniverse
from S24.omniverse.stage import load_stage

scene_path = 'database/scenes/assembly.usda'

app = start_omniverse(headless=False)
stage = load_stage(str(scene_path))

stage
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from S24.omniverse.runtime import start_omniverse
#       2 from S24.omniverse.stage import load_stage
#       4 scene_path = 'database/scenes/assembly.usda'
#
# File ~/Desktop/GC/main/GC-Sysml-OpenUSD/S24/omniverse/runtime.py:1
# ----> 1 from omni.isaac.kit import SimulationApp
#       3 def start_omniverse(headless=False):
#       4     config = {
#       5         "headless": headless,
#       6         "renderer": "RayTracedLighting"
#       7     }
#
# ModuleNotFoundError: No module named 'omni'
