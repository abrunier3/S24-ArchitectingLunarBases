# %%
from usd_writer import write_usd
import json

with open("o2tank.json", "r") as f:
    data = json.load(f)

a = write_usd(model=data["model"], output_path="o2tank_1.usd")
